# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.22.4 in .\krsri\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\krsri\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2026.1.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tzdata>=2022.7 in .\krsri\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in .\krsri\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# Downloading pytz-2026.1.post1-py2.py3-none-any.whl (510 kB)
# Installing collected packages: pytz, pandas
#
#    ---------------------------------------- 0/2 [pytz]
#    ---------------------------------------- 0/2 [pytz]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-2.3.3 pytz-2026.1.post1

# %%
import os
import time
import shutil
import cv2
import torch
import pandas as pd
from ultralytics import YOLO

# %%
from IPython import display
display.clear_output()
from IPython.display import display, Image

# %%
# !nvidia-smi
# Out:
# Sun Apr 26 17:44:26 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 581.29                 Driver Version: 581.29         CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2050      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   52C    P8              2W /   70W |       7MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           22448    C+G   ...grams\LM Studio\LM Studio.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("GPU count:", torch.cuda.device_count())
print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# CUDA version: 12.6
# GPU count: 1
# GPU name: NVIDIA GeForce RTX 2050

# %%
DATA = "dataset/Dataset KRSRI 2024 -2/data.yaml"

TEST_IMAGE = "test.jpg"

RUN_DIR = "./benchmark_runs"
EXPORT_DIR = "./trained_models"

os.makedirs(RUN_DIR, exist_ok=True)
os.makedirs(EXPORT_DIR, exist_ok=True)

RESULTS=[]

# %%
def train_benchmark(model_path):

    print("\n"+"="*70)
    print("TRAINING:",model_path)
    print("="*70)

    model_name=model_path.replace(".pt","")


    ##############################
    # MODEL-SPECIFIC BATCH
    ##############################

    batch_size=4
    if model_path=="yolov9s.pt":
        batch_size=2


    ##############################
    # LOAD PRETRAINED MODEL
    ##############################

    model=YOLO(model_path)


    ##############################
    # TRAIN
    ##############################

    start=time.time()

    model.train(
        data=DATA,
        epochs=80,
        imgsz=640,
        batch=batch_size,
        patience=5,
        save=True,
        device=0,
        amp=True,

        optimizer="AdamW",
        close_mosaic=10,

        lr0=0.001,
        lrf=0.01,
        weight_decay=0.0007,

        multi_scale=0.25,

        plots=True,
        seed=42,
        deterministic=True,

        project=RUN_DIR,
        name=model_name,
        exist_ok=False
    )

    train_minutes=(time.time()-start)/60


    ##############################
    # LOAD BEST TRAINED WEIGHT
    ##############################

    best_weight=str(model.trainer.best)

    print("Best weight:",best_weight)

    trained_model=YOLO(best_weight)


    ##############################
    # VALIDATION
    ##############################

    metrics=trained_model.val(
        split="val"
    )

    map50=float(metrics.box.map50)
    map5095=float(metrics.box.map)

    precision=float(metrics.box.mp)
    recall=float(metrics.box.mr)


    ##############################
    # MODEL SIZE
    ##############################

    size_mb=os.path.getsize(best_weight)/(1024**2)


    ####################################################
    # END-TO-END FPS (real deployment)
    ####################################################

    img=cv2.imread(TEST_IMAGE)

    for _ in range(20):
        trained_model.predict(
            img,
            device=0,
            verbose=False
        )

    torch.cuda.synchronize()

    N=100

    t1=time.time()

    for _ in range(N):
        trained_model.predict(
            img,
            device=0,
            verbose=False
        )

    torch.cuda.synchronize()

    t2=time.time()

    e2e_elapsed=t2-t1

    fps_e2e=N/e2e_elapsed
    latency_ms=(e2e_elapsed/N)*1000


    ####################################################
    # RAW MODEL FORWARD FPS
    ####################################################

    net=trained_model.model.cuda()
    net.eval()

    dummy=torch.randn(
        1,3,640,640,
        device="cuda"
    )

    for _ in range(50):
        _=net(dummy)

    torch.cuda.synchronize()

    N2=300

    t1=time.time()

    with torch.no_grad():
        for _ in range(N2):
            _=net(dummy)

    torch.cuda.synchronize()

    t2=time.time()

    raw_elapsed=t2-t1

    fps_raw=N2/raw_elapsed


    ##############################
    # COPY MODEL
    ##############################

    exported_model=(
        f"{EXPORT_DIR}/{model_name}_best.pt"
    )

    shutil.copy(
        best_weight,
        exported_model
    )


    ##############################
    # SAVE RESULTS
    ##############################

    RESULTS.append({
        "Model":model_name,

        "mAP50":map50,
        "mAP50-95":map5095,

        "Precision":precision,
        "Recall":recall,

        "FPS_E2E":fps_e2e,
        "FPS_Raw":fps_raw,

        "Latency_ms":latency_ms,

        "Size_MB":size_mb,

        "Training_Min":train_minutes
    })


    ##############################
    # PRINT
    ##############################

    print("\nDONE:",model_name)
    print("mAP50:",map50)
    print("E2E FPS:",fps_e2e)
    print("RAW FPS:",fps_raw)
    print("Latency(ms):",latency_ms)

# %%
# Jenis-jenis Yolo yang akan di benchmark
MODELS = [
    "yolov5nu.pt",
    "yolov8n.pt",
    "yolov9s.pt",
    "yolo11n.pt",
    "yolo12n.pt",
    "yolo26n.pt"
]

# %%
for i in range(len(MODELS)):
    train_benchmark(MODELS[i])
# Out:
# ======================================================================
# TRAINING: yolov5nu.pt
# ======================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov5nu.pt to 'yolov5nu.pt': 100% ━━━━━━━━━━━━ 5.3MB 774.9KB/s 7.0s.0s<0.2ss8ss
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/Dataset KRSRI 2024 -2-YOLO8/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov5nu.pt, momentum=0.937, mosaic=1.0, multi_scale=0.25, name=yolov5nu, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=./benchmark_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\KRSRI\runs\detect\benchmark_runs\yolov5nu, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0007, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1     33024  ultralytics.nn.modules.conv.Conv             [256, 128, 1, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1     90880  ultralytics.nn.modules.block.C3              [256, 128, 1, False]
#  14                  -1  1      8320  ultralytics.nn.modules.conv.Conv             [128, 64, 1, 1]
#  15                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  16             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  17                  -1  1     22912  ultralytics.nn.modules.block.C3              [128, 64, 1, False]
#  18                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  19            [-1, 14]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  20                  -1  1     74496  ultralytics.nn.modules.block.C3              [128, 128, 1, False]
#  21                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  22            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  23                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1, False]
#  24        [17, 20, 23]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# YOLOv5n summary: 154 layers, 2,509,049 parameters, 2,509,033 gradients, 7.2 GFLOPs
#
# Transferred 391/427 items from pretrained weights
# Freezing layer 'model.24.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 1.0MB/s 5.2s 5.2s<0.3sss8s
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 259.773.7 MB/s, size: 32.8 KB)
# train: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\labels.cache... 3243 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3243/3243  0.0s
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08423b181629f0d1f0284c244c362b81.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08c95355e4c90b0e34672cd16647a886.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.29f56a83b5df24783e49675e8e593b57.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 5820, len(boxes) = 6318. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.20.1 ms, read: 189.240.1 MB/s, size: 32.6 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 69 weight(decay=0.0), 76 weight(decay=0.0007), 75 bias(decay=0.0)
# Plotting labels to D:\KRSRI\runs\detect\benchmark_runs\yolov5nu\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\KRSRI\runs\detect\benchmark_runs\yolov5nu
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80       1.2G     0.6191     0.9767      1.058          7        672: 100% ━━━━━━━━━━━━ 811/811 4.5it/s 2:58<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 10.1it/s 3.9s0.2s
#                    all        309        603      0.976      0.987      0.988      0.903
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      1.28G     0.5237     0.5991     0.9884         12        736: 100% ━━━━━━━━━━━━ 811/811 6.7it/s 2:00<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 10.9it/s 3.6s0.1s
#                    all        309        603      0.975      0.987      0.989      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      1.28G     0.4891      0.528     0.9688         20        736: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:57<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.3it/s 3.5s0.2s
#                    all        309        603      0.979      0.987      0.991      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      1.28G     0.4768     0.4898      0.964         16        736: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:56<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.3it/s 3.4s0.1s
#                    all        309        603      0.991      0.993       0.99       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      1.28G     0.4456     0.4454      0.944          7        704: 100% ━━━━━━━━━━━━ 811/811 6.9it/s 1:58<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 10.8it/s 3.6s0.1s
#                    all        309        603      0.992      0.992      0.992      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      1.28G     0.4384     0.4244     0.9427         12        576: 100% ━━━━━━━━━━━━ 811/811 6.9it/s 1:57<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.6it/s 3.4s0.1s
#                    all        309        603      0.989      0.993       0.99      0.918
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      1.28G     0.4337     0.4122     0.9418         17        736: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:56<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.7it/s 3.3s0.2s
#                    all        309        603      0.969      0.987       0.99      0.945
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      1.28G     0.4147     0.3978     0.9332         17        576: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:55<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.1it/s 3.5s0.1s
#                    all        309        603      0.973       0.99      0.988      0.906
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      1.28G     0.4095     0.3915     0.9347         12        704: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:55<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.6it/s 3.4s0.1s
#                    all        309        603      0.986      0.994      0.991      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      1.28G     0.4014     0.3752     0.9243         10        544: 100% ━━━━━━━━━━━━ 811/811 6.9it/s 1:58<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.5s0.1s
#                    all        309        603      0.989      0.992      0.989      0.949
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      1.37G     0.3902     0.3652     0.9222         16        800: 100% ━━━━━━━━━━━━ 811/811 6.8it/s 1:59<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.1it/s 3.5s0.2s
#                    all        309        603      0.991      0.995       0.99      0.947
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      1.37G     0.3886     0.3594     0.9245         10        544: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:56<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.5it/s 3.4s0.1s
#                    all        309        603       0.99      0.994      0.991      0.957
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      1.37G     0.3858     0.3486     0.9181         13        672: 100% ━━━━━━━━━━━━ 811/811 7.1it/s 1:54<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.7it/s 3.3s0.2s
#                    all        309        603      0.994      0.992      0.991      0.958
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      1.37G     0.3793     0.3416     0.9158          9        544: 100% ━━━━━━━━━━━━ 811/811 7.0it/s 1:55<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.5it/s 3.4s0.2s
#                    all        309        603      0.993      0.989      0.989      0.958
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 9, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 14 epochs completed in 0.487 hours.
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolov5nu\weights\last.pt, 5.3MB
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolov5nu\weights\best.pt, 5.3MB
#
# Validating D:\KRSRI\runs\detect\benchmark_runs\yolov5nu\weights\best.pt...
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLOv5n summary (fused): 85 layers, 2,503,529 parameters, 0 gradients, 7.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 10.6it/s 3.7s0.2s
#                    all        309        603      0.986      0.994      0.991      0.958
#                  Dummy        199        295      0.986      0.981      0.989       0.93
#                 Korban        197        198      0.978          1       0.99      0.959
#                 Tangga        110        110      0.994          1      0.995      0.984
# Speed: 0.3ms preprocess, 3.8ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\benchmark_runs\yolov5nu
# Best weight: D:\KRSRI\runs\detect\benchmark_runs\yolov5nu\weights\best.pt
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLOv5n summary (fused): 85 layers, 2,503,529 parameters, 0 gradients, 7.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 268.661.3 MB/s, size: 36.0 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.6s0.2s
#                    all        309        603      0.986      0.994      0.991      0.957
#                  Dummy        199        295      0.986      0.981      0.989      0.928
#                 Korban        197        198      0.978          1       0.99      0.957
#                 Tangga        110        110      0.994          1      0.995      0.986
# Speed: 2.2ms preprocess, 6.8ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\val
#
# DONE: yolov5nu
# mAP50: 0.9914495307610537
# E2E FPS: 57.3205579069919
# RAW FPS: 83.13038599710617
# Latency(ms): 17.44574785232544
#
# ======================================================================
# TRAINING: yolov8n.pt
# ======================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 3.2MB/s 2.0s.9s<0.1s1.8s
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/Dataset KRSRI 2024 -2-YOLO8/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.25, name=yolov8n, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=./benchmark_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\KRSRI\runs\detect\benchmark_runs\yolov8n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0007, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751897  ultralytics.nn.modules.head.Detect           [3, 16, None, [64, 128, 256]]
# Model summary: 130 layers, 3,011,433 parameters, 3,011,417 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 254.869.2 MB/s, size: 35.0 KB)
# train: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\labels.cache... 3243 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3243/3243  0.0s
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08423b181629f0d1f0284c244c362b81.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08c95355e4c90b0e34672cd16647a886.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.29f56a83b5df24783e49675e8e593b57.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 5820, len(boxes) = 6318. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.10.0 ms, read: 138.582.4 MB/s, size: 33.4 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0007), 63 bias(decay=0.0)
# Plotting labels to D:\KRSRI\runs\detect\benchmark_runs\yolov8n\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\KRSRI\runs\detect\benchmark_runs\yolov8n
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      0.91G       0.58     0.9093      1.003          7        512: 100% ━━━━━━━━━━━━ 811/811 6.8it/s 1:59<0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.0it/s 3.6s0.1s
#                    all        309        603      0.987      0.974      0.989        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      0.91G     0.5028     0.5678     0.9634         12        576: 100% ━━━━━━━━━━━━ 811/811 7.7it/s 1:45<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.4it/s 3.4s0.2s
#                    all        309        603      0.982      0.989      0.991       0.92
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      0.91G     0.4825     0.5148     0.9622         20        736: 100% ━━━━━━━━━━━━ 811/811 8.0it/s 1:41<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11
0.969
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       48/80      0.91G     0.2823     0.2256     0.8829         11        800: 100% ━━━━━━━━━━━━ 811/811 8.2it/s 1:39<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.7it/s 3.3s0.1s
#                    all        309        603      0.993      0.996      0.992      0.969
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       49/80      0.91G     0.2847     0.2244     0.8858          7        672: 100% ━━━━━━━━━━━━ 811/811 8.3it/s 1:38<0.1ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.4it/s 3.4s0.1s
#                    all        309        603      0.994      0.996      0.993      0.971
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 44, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 49 epochs completed in 1.420 hours.
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolov8n\weights\last.pt, 6.3MB
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolov8n\weights\best.pt, 6.3MB
#
# Validating D:\KRSRI\runs\detect\benchmark_runs\yolov8n\weights\best.pt...
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 11.7it/s 3.3s0.1s
#                    all        309        603      0.994      0.996      0.992      0.973
#                  Dummy        199        295      0.993      0.987      0.989      0.946
#                 Korban        197        198      0.993          1       0.99      0.978
#                 Tangga        110        110      0.996          1      0.995      0.995
# Speed: 0.3ms preprocess, 3.9ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\benchmark_runs\yolov8n
# Best weight: D:\KRSRI\runs\detect\benchmark_runs\yolov8n\weights\best.pt
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# Model summary (fused): 73 layers, 3,006,233 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 279.841.7 MB/s, size: 32.3 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.3it/s 4.7s0.2s
#                    all        309        603      0.994      0.996      0.992      0.974
#                  Dummy        199        295      0.993      0.987      0.989      0.947
#                 Korban        197        198      0.993          1       0.99      0.979
#                 Tangga        110        110      0.996          1      0.995      0.995
# Speed: 2.2ms preprocess, 7.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\val-2
#
# DONE: yolov8n
# mAP50: 0.9915571687643419
# E2E FPS: 65.31192905838516
# RAW FPS: 92.52202404280617
# Latency(ms): 15.31113862991333
#
# ======================================================================
# TRAINING: yolov9s.pt
# ======================================================================
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolov9s.pt to 'yolov9s.pt': 2% ──────────── 252.1KB/14.7MB 81.7B/s 7:19<51:28:08
# WARNING Partial download: 258106/15389259 bytes (1.7%)
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# ...
# TRAINING: yolo26n.pt
# ======================================================================
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# engine\trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=4, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=dataset/Dataset KRSRI 2024 -2-YOLO8/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=80, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.25, name=yolo26n, nbs=64, nms=False, opset=None, optimize=False, optimizer=AdamW, overlap_mask=True, patience=5, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=./benchmark_runs, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=D:\KRSRI\runs\detect\benchmark_runs\yolo26n, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=42, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0007, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242346  ultralytics.nn.modules.head.Detect           [3, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,504,970 parameters, 2,504,970 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.10.0 ms, read: 271.584.5 MB/s, size: 35.0 KB)
# train: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\labels.cache... 3243 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3243/3243  0.0s
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08423b181629f0d1f0284c244c362b81.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.08c95355e4c90b0e34672cd16647a886.jpg: 1 duplicate labels removed
# train: D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\train\images\k346_png.rf.29f56a83b5df24783e49675e8e593b57.jpg: 1 duplicate labels removed
# WARNING Box and segment counts should be equal, but got len(segments) = 5820, len(boxes) = 6318. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# val: Fast image access  (ping: 0.10.0 ms, read: 186.0123.8 MB/s, size: 33.4 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
# optimizer: AdamW(lr=0.001, momentum=0.937) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0007), 126 bias(decay=0.0)
# Plotting labels to D:\KRSRI\runs\detect\benchmark_runs\yolo26n\labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to D:\KRSRI\runs\detect\benchmark_runs\yolo26n
# Starting training for 80 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/80      1.09G     0.7763      1.354    0.01061          7        512: 100% ━━━━━━━━━━━━ 811/811 3.9it/s 3:27<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.2it/s 4.3s0.1s
#                    all        309        603       0.85      0.806      0.908      0.831
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/80      1.09G     0.6123     0.7444   0.007746         12        576: 100% ━━━━━━━━━━━━ 811/811 4.6it/s 2:58<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.6it/s 4.1s0.1s
#                    all        309        603      0.881      0.919      0.958       0.88
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/80      1.09G     0.5656     0.6385   0.007223         20        736: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:49<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.7it/s 4.0s<0.2s
#                    all        309        603      0.858      0.923      0.957        0.9
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/80      1.09G     0.5353     0.5576     0.0065         16        704: 100% ━━━━━━━━━━━━ 811/811 4.7it/s 2:52<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.3it/s 4.2s0.1s
#                    all        309        603      0.919      0.937      0.968      0.892
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/80      1.09G     0.5297     0.5056   0.006417          7        672: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:48<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.3it/s 4.2s0.2s
#                    all        309        603      0.933      0.945      0.981      0.931
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/80      1.09G     0.5052     0.4697   0.006114         12        512: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.6it/s 4.1s0.1s
#                    all        309        603      0.907      0.929      0.961      0.902
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/80      1.09G     0.4973     0.4515   0.005961         17        544: 100% ━━━━━━━━━━━━ 811/811 4.7it/s 2:52<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.3it/s 4.2s0.1s
#                    all        309        603      0.944      0.939      0.983      0.916
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/80      1.09G     0.4834     0.4226   0.005753         17        480: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 8.9it/s 4.4s0.2s
#                    all        309        603      0.858      0.943      0.972      0.928
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/80      1.09G     0.4791     0.4014   0.005769         12        800: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.2it/s 4.3s0.1s
#                    all        309        603       0.95      0.966      0.981      0.934
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/80      1.09G     0.4696     0.3903   0.005472         10        640: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.0it/s 4.3s0.1s
#                    all        309        603      0.972      0.947      0.986      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/80      1.09G      0.454     0.3687   0.005287         16        672: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:51<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.6it/s 4.1s0.2s
#                    all        309        603      0.958      0.961      0.984      0.951
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/80      1.09G     0.4669     0.3692   0.005554         10        608: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.3it/s 4.2s0.2s
#                    all        309        603      0.943      0.961      0.985      0.956
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/80      1.09G     0.4499     0.3536    0.00533         13        576: 100% ━━━━━━━━━━━━ 811/811 4.7it/s 2:51<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.8it/s 4.0s0.1ss
#                    all        309        603      0.967      0.959      0.985      0.955
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/80      1.09G      0.437     0.3424   0.004957          9        768: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:48<0.3s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.6it/s 4.1s0.2s
#                    all        309        603      0.955      0.957      0.984       0.94
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/80      1.09G     0.4356     0.3405    0.00488         13        544: 100% ━━━━━━━━━━━━ 811/811 4.8it/s 2:50<0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 9.5it/s 4.1s0.1ss
#                    all        309        603      0.934      0.915      0.975      0.943
# EarlyStopping: Training stopped early as no improvement observed in last 5 epochs. Best results observed at epoch 10, best model saved as best.pt.
# To update EarlyStopping(patience=5) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 15 epochs completed in 0.742 hours.
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolo26n\weights\last.pt, 5.4MB
# Optimizer stripped from D:\KRSRI\runs\detect\benchmark_runs\yolo26n\weights\best.pt, 5.4MB
#
# Validating D:\KRSRI\runs\detect\benchmark_runs\yolo26n\weights\best.pt...
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 39/39 12.1it/s 3.2s0.2s
#                    all        309        603      0.972      0.949      0.986      0.957
#                  Dummy        199        295      0.985      0.881      0.979      0.919
#                 Korban        197        198      0.946      0.964      0.985      0.958
#                 Tangga        110        110      0.985          1      0.995      0.992
# Speed: 0.3ms preprocess, 4.4ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\benchmark_runs\yolo26n
# Best weight: D:\KRSRI\runs\detect\benchmark_runs\yolo26n\weights\best.pt
# Ultralytics 8.4.41  Python-3.10.5 torch-2.11.0+cu126 CUDA:0 (NVIDIA GeForce RTX 2050, 4096MiB)
# YOLO26n summary (fused): 122 layers, 2,375,421 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 218.349.2 MB/s, size: 34.2 KB)
# val: Scanning D:\KRSRI\dataset\Dataset KRSRI 2024 -2-YOLO8\valid\labels.cache... 309 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 309/309  0.0s
# WARNING Box and segment counts should be equal, but got len(segments) = 550, len(boxes) = 603. To resolve this only boxes will be used and all segments will be removed. To avoid this please supply either a detect or segment dataset, not a detect-segment mixed dataset.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 20/20 4.4it/s 4.5s0.2s
#                    all        309        603      0.972      0.947      0.986      0.956
#                  Dummy        199        295      0.985      0.881      0.979      0.919
#                 Korban        197        198      0.945      0.961      0.985      0.957
#                 Tangga        110        110      0.985          1      0.995      0.991
# Speed: 2.3ms preprocess, 7.7ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to D:\KRSRI\runs\detect\val-6
#
# DONE: yolo26n
# mAP50: 0.9864027160741372
# E2E FPS: 48.64746874040952
# RAW FPS: 58.60388119410982
# Latency(ms): 20.55605411529541

# %%
df = pd.DataFrame(RESULTS)

df.to_csv(
    "benchmark_results.csv",
    index=False
)

print("\nBenchmark selesai.")
print(df)
# Out:
# Benchmark selesai.
#       Model     mAP50  mAP50-95  Precision    Recall    FPS_E2E    FPS_Raw  \
# 0  yolov5nu  0.991450  0.957035   0.986009  0.993721  57.320558  83.130386
# 1   yolov8n  0.991557  0.973797   0.994079  0.995654  65.311929  92.522024
# 2   yolov9s  0.989815  0.960026   0.987344  0.995296  26.748178  30.208653
# 3   yolo11n  0.990103  0.958301   0.987080  0.993775  48.141841  72.662919
# 4   yolo12n  0.989160  0.963693   0.994788  0.994536  34.202825  42.737510
# 5   yolo26n  0.986403  0.955796   0.971831  0.947246  48.647469  58.603881
#
#    Latency_ms    Size_MB  Training_Min
# 0   17.445748   5.023134     30.140428
# 1   15.311139   5.960489     85.979723
# 2   37.385724  14.519967     94.503347
# 3   20.771952   5.215052     39.610919
# 4   29.237351   5.259607     55.589635
# 5   20.556054   5.134282     45.345216
